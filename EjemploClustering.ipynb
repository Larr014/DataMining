# %% [markdown]
# <a href="https://colab.research.google.com/github/Larr014/DataMining/blob/master/EjemploClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df =df.drop(['PassengerId','Name','SibSp','Parch',"Ticket","Fare","Cabin","Embarked"],axis=1)
df
# Out:
#      Survived  Pclass     Sex   Age
# 0           0       3    male  22.0
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 4           0       3    male  35.0
# ..        ...     ...     ...   ...
# 886         0       2    male  27.0
# 887         1       1  female  19.0
# 888         0       3  female   NaN
# 889         1       1    male  26.0
# 890         0       3    male  32.0
#
# [891 rows x 4 columns]

# %%
df['Sex']  = [1 if x=="female" else 0 for x in df['Sex']]
df['Sex']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
df = df.dropna()
df
# Out:
#      Survived  Pclass  Sex   Age
# 0           0       3    0  22.0
# 1           1       1    1  38.0
# 2           1       3    1  26.0
# 3           1       1    1  35.0
# 4           0       3    0  35.0
# ..        ...     ...  ...   ...
# 885         0       3    1  39.0
# 886         0       2    0  27.0
# 887         1       1    1  19.0
# 889         1       1    0  26.0
# 890         0       3    0  32.0
#
# [714 rows x 4 columns]

# %%
df['Sex']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    1
# 886    0
# 887    1
# 889    0
# 890    0
# Name: Sex, Length: 714, dtype: int64

# %%
df
# Out:
#      Survived  Pclass  Sex   Age
# 0           0       3    0  22.0
# 1           1       1    1  38.0
# 2           1       3    1  26.0
# 3           1       1    1  35.0
# 4           0       3    0  35.0
# ..        ...     ...  ...   ...
# 885         0       3    1  39.0
# 886         0       2    0  27.0
# 887         1       1    1  19.0
# 889         1       1    0  26.0
# 890         0       3    0  32.0
#
# [714 rows x 4 columns]

# %%
features = df.values

# %%
from sklearn.cluster import KMeans
common_params = {
    "n_init": "auto",
    "random_state": 2,
}
modelo = KMeans(n_clusters=10, **common_params)
y_pred = modelo.fit_predict(features)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, random_state=0)
reduced_features = pca.fit_transform(features)
reduced_cluster_centers = pca.transform(modelo.cluster_centers_)
y_pred = modelo.predict(features)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.scatter(reduced_features[:,0], reduced_features[:,1], c=y_pred)
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='b')
ax.grid(True)
ax.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
len(y_pred)
# Out:
# 714

# %%
df.reset_index(inplace=True, drop=False)

# %%
ndf = df.copy()
ndf = pd.concat([ndf, pd.DataFrame(y_pred)], axis=1)
ndf
# Out:
#      index  Survived  Pclass  Sex   Age  0
# 0        0         0       3    0  22.0  0
# 1        1         1       1    1  38.0  6
# 2        2         1       3    1  26.0  0
# 3        3         1       1    1  35.0  3
# 4        4         0       3    0  35.0  3
# ..     ...       ...     ...  ...   ... ..
# 709    885         0       3    1  39.0  6
# 710    886         0       2    0  27.0  8
# 711    887         1       1    1  19.0  5
# 712    889         1       1    0  26.0  0
# 713    890         0       3    0  32.0  3
#
# [714 rows x 6 columns]

# %%
ndf.rename(columns={0:"Cluster"},inplace=True)
ndf
# Out:
#      index  Survived  Pclass  Sex   Age  Cluster
# 0        0         0       3    0  22.0        0
# 1        1         1       1    1  38.0        6
# 2        2         1       3    1  26.0        0
# 3        3         1       1    1  35.0        3
# 4        4         0       3    0  35.0        3
# ..     ...       ...     ...  ...   ...      ...
# 709    885         0       3    1  39.0        6
# 710    886         0       2    0  27.0        8
# 711    887         1       1    1  19.0        5
# 712    889         1       1    0  26.0        0
# 713    890         0       3    0  32.0        3
#
# [714 rows x 6 columns]

# %%
ndf[ndf["Cluster"]==0]
# Out:
#      index  Survived  Pclass  Sex   Age  Cluster
# 0        0         0       3    0  22.0        0
# 2        2         1       3    1  26.0        0
# 28      37         0       3    0  21.0        0
# 37      51         0       3    0  21.0        0
# 41      56         1       2    1  21.0        0
# ..     ...       ...     ...  ...   ...      ...
# 695    870         0       3    0  26.0        0
# 704    880         1       2    1  25.0        0
# 706    882         0       3    1  22.0        0
# 708    884         0       3    0  25.0        0
# 712    889         1       1    0  26.0        0
#
# [140 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...
